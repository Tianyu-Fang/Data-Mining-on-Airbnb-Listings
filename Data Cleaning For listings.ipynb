# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import numpy.random as nr
import math

# %matplotlib inline

# %%
listings_csv = pd.read_csv('./dataset/listings.csv')
print(listings_csv.columns)
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary',
#        'space', 'description', 'experiences_offered', 'neighborhood_overview',
#        'notes', 'transit', 'access', 'interaction', 'house_rules',
#        'thumbnail_url', 'medium_url', 'picture_url', 'xl_picture_url',
#        'host_id', 'host_url', 'host_name', 'host_since', 'host_location',
#        'host_about', 'host_response_time', 'host_response_rate',
#        'host_acceptance_rate', 'host_is_superhost', 'host_thumbnail_url',
#        'host_picture_url', 'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'street',
#        'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market',
#        'smart_location', 'country_code', 'country', 'latitude', 'longitude',
# ...

# %%
(listings_csv.astype(np.object) == '?').any()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_26504\1827065305.py:1: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   (listings_csv.astype(np.object) == '?').any()
# id                                  False
# listing_url                         False
# scrape_id                           False
# last_scraped                        False
# name                                False
#                                     ...
# cancellation_policy                 False
# require_guest_profile_picture       False
# require_guest_phone_verification    False
# calculated_host_listings_count      False
# reviews_per_month                   False
# Length: 95, dtype: bool

# %%
# listings_csv.dtypes
listings_csv.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3585 entries, 0 to 3584
# Data columns (total 95 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                3585 non-null   int64
#  1   listing_url                       3585 non-null   object
#  2   scrape_id                         3585 non-null   int64
#  3   last_scraped                      3585 non-null   object
#  4   name                              3585 non-null   object
#  5   summary                           3442 non-null   object
#  6   space                             2528 non-null   object
#  7   description                       3585 non-null   object
#  8   experiences_offered               3585 non-null   object
#  9   neighborhood_overview             2170 non-null   object
#  10  notes                             1610 non-null   object
# ...

# %%
listings_csv.drop(['neighbourhood_group_cleansed', 'square_feet', 'has_availability', 'license', 'jurisdiction_names'], axis=1, inplace=True)

# %%
print(listings_csv['reviews_per_month'])
# Out:
# 0        NaN
# 1       1.30
# 2       0.47
# 3       1.00
# 4       2.25
#         ...
# 3580    0.34
# 3581     NaN
# 3582     NaN
# 3583    2.00
# 3584     NaN
# Name: reviews_per_month, Length: 3585, dtype: float64

# %%
# listings_csv['host_response_rate'].value_counts()

# %%
for col in listings_csv.columns:
    if listings_csv[col].dtype == 'int64':
        count = 0
        count = [count + 1 for x in listings_csv[col] if x == ' ']
        print(col + ' ' + str(sum(count)))
# Out:
# id 0
# scrape_id 0
# host_id 0
# host_listings_count 0
# host_total_listings_count 0
# accommodates 0
# guests_included 0
# minimum_nights 0
# maximum_nights 0
# availability_30 0
# availability_60 0
# availability_90 0
# availability_365 0
# number_of_reviews 0
# calculated_host_listings_count 0

# %%
print(listings_csv['host_response_rate'])
# Out:
# 0        NaN
# 1       100%
# 2       100%
# 3       100%
# 4       100%
#         ...
# 3580     96%
# 3581     10%
# 3582     78%
# 3583    100%
# 3584    100%
# Name: host_response_rate, Length: 3585, dtype: object

# %%
# delete rows with empty/null values
listings_csv = listings_csv.dropna()

# %%
listings_csv.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 74 entries, 40 to 3524
# Data columns (total 90 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                74 non-null     int64
#  1   listing_url                       74 non-null     object
#  2   scrape_id                         74 non-null     int64
#  3   last_scraped                      74 non-null     object
#  4   name                              74 non-null     object
#  5   summary                           74 non-null     object
#  6   space                             74 non-null     object
#  7   description                       74 non-null     object
#  8   experiences_offered               74 non-null     object
#  9   neighborhood_overview             74 non-null     object
#  10  notes                             74 non-null     object
# ...

# %%
print(listings_csv)
# Out:
#             id                            listing_url       scrape_id  \
# 40     3755609   https://www.airbnb.com/rooms/3755609  20160906204935
# 44     1724900   https://www.airbnb.com/rooms/1724900  20160906204935
# 47     1494726   https://www.airbnb.com/rooms/1494726  20160906204935
# 52     1721016   https://www.airbnb.com/rooms/1721016  20160906204935
# 70     5601743   https://www.airbnb.com/rooms/5601743  20160906204935
# ...        ...                                    ...             ...
# 3292   5384923   https://www.airbnb.com/rooms/5384923  20160906204935
# 3309   3677662   https://www.airbnb.com/rooms/3677662  20160906204935
# 3390  13019695  https://www.airbnb.com/rooms/13019695  20160906204935
# 3507   8751275   https://www.airbnb.com/rooms/8751275  20160906204935
# 3524   8704828   https://www.airbnb.com/rooms/8704828  20160906204935
#
#      last_scraped                                name  \
# 40     2016-09-07    Lovely & Gracious Victorian room
# ...
